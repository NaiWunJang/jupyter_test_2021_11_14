# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.arange(0,12.1,0.1)
Y = np.sin(X)

# %%
plt.plot(X,Y)

# %%
plt.plot(X,Y, 'r--')

# %%
plt.plot(X,Y, 'r:')

# %%
plt.plot(X,Y, 'r-.')
